# %%
# !python follow_anything.py
# Out:
# Init tracker...
# Initializing Segmentor to 0
# c:\Users\Arup\Downloads\FollowAnything-main\FollowAnything-main\follow_anything.py:107: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = matplotlib.cm.get_cmap("jet")
# c:\Users\Arup\Downloads\FollowAnything-main\FollowAnything-main\follow_anything.py:899: DeprecationWarning: There is no current event loop
#   loop = asyncio.get_event_loop()
# Traceback (most recent call last):
#   File "c:\Users\Arup\Downloads\FollowAnything-main\FollowAnything-main\follow_anything.py", line 905, in <module>
#     device, tracker_cfg, cfg, tracker, detector, segmentor, queries, video, vehicle = init_system()
#                                                                                       ~~~~~~~~~~~^^
# ...

# %%
# !pip install opencv-python torch mavsdk rtsp scipy open_clip_torch segment_anything scikit-image matplotlib numpy
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
